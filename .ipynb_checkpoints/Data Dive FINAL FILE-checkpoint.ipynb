# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
preliminary_df = pd.read_csv('chm_jail_data.csv', na_values = ['nan', 'Unknown', 'Other'])
preliminary_df
# Out:
# /var/folders/rz/99x91dzn46xdnlv1swhwtc9r0000gn/T/ipykernel_14666/1251039999.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   preliminary_df = pd.read_csv('chm_jail_data.csv', na_values = ['nan', 'Unknown', 'Other'])
#        booking_number booking_date booking_time  jacket_number jacket_type  \
# 0        201200000001     1/1/2012      0:19:14          22914           A
# 1        201200000001     1/1/2012      0:19:14          22914           A
# 2        201200000001     1/1/2012      0:19:14          22914           A
# 3        201200000002     1/1/2012      1:44:45        1024225           A
# 4        201200000002     1/1/2012      1:44:45        1024225           A
# ...               ...          ...          ...            ...         ...
# 67918    201800002539    6/30/2018     12:36:48        1069755           A
# 67919    201800002540    6/30/2018     19:26:59        1000385           A
# ...

# %%
preliminary_df.groupby(by= 'jacket_number').agg('count').reset_index()
# Out:
#        jacket_number  booking_number  booking_date  booking_time  jacket_type  \
# 0               6265               1             1             1            1
# 1               6565               6             6             6            6
# 2               6684               1             1             1            1
# 3               7188               2             2             2            2
# 4               7594               4             4             4            4
# ...              ...             ...           ...           ...          ...
# 19609        1069761               1             1             1            1
# 19610        1069763               1             1             1            1
# 19611        1069766               3             3             3            3
# 19612        1069768               2             2             2            2
# 19613        1069774               3             3             3            3
#
# ...

# %%
df = preliminary_df[['booking_date', 'released_date', 'jacket_number', 'arrest_agency', 'age_at_arrest', 'age_at_release', 'hours', 'marital_status', 'employment_status', 'city', 'race', 'sex', 'STATE', 'citizenship', 'occupation', 'school', 'prisoner_type', 'offense_level']]
df
# Out:
#       booking_date released_date  jacket_number  \
# 0         1/1/2012      1/1/2012          22914
# 1         1/1/2012      1/1/2012          22914
# 2         1/1/2012      1/1/2012          22914
# 3         1/1/2012      1/2/2012        1024225
# 4         1/1/2012      1/2/2012        1024225
# ...            ...           ...            ...
# 67918    6/30/2018     6/30/2018        1069755
# 67919    6/30/2018     6/30/2018        1000385
# 67920    6/30/2018     6/30/2018         990152
# 67921    6/30/2018      7/1/2018          34365
# 67922    6/30/2018      7/2/2018        1060848
#
#                                   arrest_agency  age_at_arrest  \
# 0                   Champaign Police Department           51.0
# 1                   Champaign Police Department           51.0
# 2                   Champaign Police Department           51.0
# 3                   Champaign Police Department           32.0
# 4                   Champaign Police Department           32.0
# ...

# %%
grouped_data = df.groupby('jacket_number').agg('count').reset_index()
grouped_data
# Out:
#        jacket_number  booking_date  released_date  arrest_agency  \
# 0               6265             1              1              1
# 1               6565             6              6              6
# 2               6684             1              1              1
# 3               7188             2              2              2
# 4               7594             4              4              4
# ...              ...           ...            ...            ...
# 19609        1069761             1              1              1
# 19610        1069763             1              1              1
# 19611        1069766             3              3              3
# 19612        1069768             2              2              2
# 19613        1069774             3              3              3
#
#        age_at_arrest  age_at_release  hours  marital_status  \
# 0                  1               1      1               1
# 1                  6               6      6               6
# ...

# %%
both_groups = grouped_data.groupby('booking_date').agg('count').reset_index()
both_groups
# Out:
#     booking_date  jacket_number  released_date  arrest_agency  age_at_arrest  \
# 0              1           7282           7282           7282           7282
# 1              2           3756           3756           3756           3756
# 2              3           2716           2716           2716           2716
# 3              4           1539           1539           1539           1539
# 4              5           1084           1084           1084           1084
# 5              6            730            730            730            730
# 6              7            531            531            531            531
# 7              8            402            402            402            402
# 8              9            295            295            295            295
# 9             10            230            230            230            230
# 10            11            179            179            179            179
# ...

# %%
df['repeat_offender'] = grouped_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rz/99x91dzn46xdnlv1swhwtc9r0000gn/T/ipykernel_14666/1133490910.py in ?()
# ----> 1 df['repeat_offender'] = grouped_data
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#    3943             and not self.columns.is_unique
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4090             self._set_item_mgr(key, arraylike)
#    4091             return
#    4092
# ...

# %%
df_dropNa = df.dropna()
df_dropNa
# Out:
#       booking_date released_date  jacket_number  \
# 0         1/1/2012      1/1/2012          22914
# 1         1/1/2012      1/1/2012          22914
# 2         1/1/2012      1/1/2012          22914
# 3         1/1/2012      1/2/2012        1024225
# 4         1/1/2012      1/2/2012        1024225
# ...            ...           ...            ...
# 67918    6/30/2018     6/30/2018        1069755
# 67919    6/30/2018     6/30/2018        1000385
# 67920    6/30/2018     6/30/2018         990152
# 67921    6/30/2018      7/1/2018          34365
# 67922    6/30/2018      7/2/2018        1060848
#
#                                   arrest_agency  age_at_arrest  \
# 0                   Champaign Police Department           51.0
# 1                   Champaign Police Department           51.0
# 2                   Champaign Police Department           51.0
# 3                   Champaign Police Department           32.0
# 4                   Champaign Police Department           32.0
# ...

# %%
df_filtered.isna().sum()
# Out:
# booking_date            0
# released_date           0
# arrest_agency         885
# age_at_arrest         462
# age_at_release        462
# hours                   0
# marital_status        383
# employment_status     857
# city                  274
# race                  818
# sex                   462
# STATE                 307
# citizenship           655
# occupation           2661
# school               4191
# prisoner_type         401
# offense_level         401
# dtype: int64
