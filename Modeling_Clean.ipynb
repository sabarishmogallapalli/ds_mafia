# %%
pip install libomp
# Out:
# ERROR: Could not find a version that satisfies the requirement libomp (from versions: none)
# ERROR: No matching distribution found for libomp
# Note: you may need to restart the kernel to use updated packages.

# %%
import pycaret

# %%
from pycaret.datasets import get_data
data = get_data("CLEAN_chm_jail_data")
# Out:
#   booking_date  jacket_number  age_at_arrest  age_at_release  hours  \
# 0     1/1/2012          22914           51.0            51.0      1
# 1     1/1/2012        1024225           32.0            32.0     32
# 2     1/1/2012        1024226           20.0            20.0     12
# 3     1/1/2012        1024227           20.0            20.0     10
# 4     1/1/2012        1024228           17.0            17.0     10
#
#   marital_status     employment_status       city   race   sex  ... city_no  \
# 0       Divorced  Employed - Full Time  CHAMPAIGN  Black  Male  ...       0
# 1         Single  Employed - Full Time  CHAMPAIGN  Black  Male  ...       0
# 2         Single  Employed - Part Time  CHAMPAIGN  Black  Male  ...       0
# 3         Single            Unemployed  CHAMPAIGN  Black  Male  ...       0
# 4         Single            Unemployed  CHAMPAIGN  Black  Male  ...       0
#
#   race_no sex_no STATE_no citizenship_no  occupation_no  school_no  \
# 0       0      0        0              0              4          0
# 1       0      0        0              0              0          0
# 2       0      0        0              0              8          0
# 3       0      0        0              0              2          0
# 4       0      0        0              0              0          0
#
#    prisoner_type_no      r  r_count
# 0                 0   True        1
# 1                 2   True        4
# 2                 0  False        0
# 3                 2  False        0
# 4                 3   True        6
#
# [5 rows x 27 columns]

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(data, target = 'r_count', session_id = 123)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 3
#       1 from pycaret.classification import ClassificationExperiment
#       2 s = ClassificationExperiment()
# ----> 3 s.setup(data, target = 'r_count', session_id = 123)
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/classification/oop.py:715, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     712 self.fold_shuffle_param = fold_shuffle
#     713 self.fold_groups_param = fold_groups
# --> 715 self._initialize_setup(
#     716     n_jobs=n_jobs,
#     717     use_gpu=use_gpu,
#     718     html=html,
#     719     session_id=session_id,
#     720     system_log=system_log,
#     721     log_experiment=log_experiment,
#     722     experiment_name=experiment_name,
#     723     memory=memory,
#     724     verbose=verbose,
#     725 )
#     727 # Prepare experiment specific params ======================= >>
#     729 self.log_plots_param = log_plots
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:328, in _TabularExperiment._initialize_setup(self, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, memory, verbose)
#     324 self.logger.info(f"self.USI: {self.USI}")
#     326 self.logger.info(f"self._variable_keys: {self._variable_keys}")
# --> 328 self._check_environment()
#     330 # Set up GPU usage ========================================= >>
#     332 if self.gpu_param != "force" and type(self.gpu_param) is not bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/pycaret_experiment.py:121, in _PyCaretExperiment._check_environment(self)
#     118 from pycaret.utils._show_versions import show_versions
#     120 self.logger.info("Checking libraries")
# --> 121 self.logger.info(show_versions(logger=self.logger))
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/utils/_show_versions.py:165, in show_versions(optional, logger)
#     162     print_func("{k:>10}: {stat}".format(k=k, stat=stat))  # noqa: T001
#     164 print_func(f"{prefix}PyCaret required dependencies:")  # noqa: T001
# --> 165 optional_deps_info = _get_deps_info(logger=logger)
#     166 for k, stat in optional_deps_info.items():
#     167     print_func("{k:>20}: {stat}".format(k=k, stat=stat))  # noqa: T001
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/utils/_show_versions.py:130, in _get_deps_info(optional, logger)
#     128 for modname in deps:
#     129     try:
# --> 130         ver = get_module_version(modname)
#     131         if not ver:
#     132             ver = "Installed but version unavailable"
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/utils/_dependencies.py:81, in get_module_version(modname)
#      79 def get_module_version(modname: str) -> Optional[LooseVersion]:
#      80     """Raises a ValueError if module is not installed"""
# ---> 81     version = _get_module_version(modname)
#      82     if version is False:
#      83         raise ValueError(f"Module '{modname}' is not installed.")
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/utils/_dependencies.py:75, in _get_module_version(modname)
#      72 installed_modules = get_installed_modules()
#      73 if modname not in installed_modules:
#      74     # Fallback. This should never happen unless module is not present
# ---> 75     installed_modules[modname] = _try_import_and_get_module_version(modname)
#      76 return installed_modules[modname]
#
# File ~/anaconda3/lib/python3.11/site-packages/pycaret/utils/_dependencies.py:28, in _try_import_and_get_module_version(modname)
#      26 if logger:
#      27     with redirect_output(logger):
# ---> 28         mod = import_module(modname)
#      29 else:
#      30     mod = import_module(modname)
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~/anaconda3/lib/python3.11/site-packages/lightgbm/basic.py:247
#     245     _LIB = Mock(ctypes.CDLL)  # type: ignore
#     246 else:
# --> 247     _LIB = _load_lib()
#     250 _NUMERIC_TYPES = (int, float, bool)
#     251 _ArrayLike = Union[List, np.ndarray, pd_Series]
#
# File ~/anaconda3/lib/python3.11/site-packages/lightgbm/basic.py:232, in _load_lib()
#     230 """Load LightGBM library."""
#     231 lib_path = find_lib_path()
# --> 232 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     233 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     234 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File ~/anaconda3/lib/python3.11/ctypes/__init__.py:454, in LibraryLoader.LoadLibrary(self, name)
#     453 def LoadLibrary(self, name):
# --> 454     return self._dlltype(name)
#
# File ~/anaconda3/lib/python3.11/ctypes/__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 self._FuncPtr = _FuncPtr
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#     378     self._handle = handle
#
# OSError: dlopen(/Users/samuelhaskel/anaconda3/lib/python3.11/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <C3EB28DD-60B6-3334-AFA2-72BBBF9DBAEF> /Users/samuelhaskel/anaconda3/lib/python3.11/site-packages/lightgbm/lib/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
